# %% [markdown]
# # set

# %%
# 여러개의 데이터를 담는 집합 데이터 타입들..
#1. list   :  순서있다.  중복허용,  mutable
#2. tuple  :  순서있다,  중복허용,  immutable
#3. set : 순서없다,  중복허용안함
#4. dict : key, value 쌍으로 구성, 순서없다.

# %%
# set
# 만드는 방법
# 1.set(iterable)  함수로 만들수도 있고
# 2. {  } 으로 만들수도 있다.

# %%
animals = {"dog", "cat", "dog", "bird"}

animals  # 중복허용 안함, 순서 유지 안됨.
# Out:
# {'bird', 'cat', 'dog'}

# %%
type(animals)
# Out:
# set

# %%
len(animals)
# Out:
# 3

# %%
animals[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-b058c8ae0f95> in <cell line: 0>()
# ----> 1 animals[0]
#
# TypeError: 'set' object is not subscriptable

# %%
animals = ["dog", "dog", "cat", "bird"]
# 위 list 에서 중복된 데이터를 제거하고
# 싶다면?

# %%
list(set(animals))
# Out:
# ['bird', 'cat', 'dog']

# %%
# 빈 set 만들기

a = {}  # 이건 dict 다!

type(a)
# Out:
# dict

# %%
a = set()  # 빈 set 만들기

a
# Out:
# set()

# %%
type(a)
# Out:
# set

# %%
len(a)
# Out:
# 0

# %% [markdown]
# # add(), remove()

# %%
a.add("dog")

# %%
a
# Out:
# {'dog'}

# %%
a.add('cat')

a
# Out:
# {'cat', 'dog'}

# %%
a.remove('dog')

a
# Out:
# {'cat'}

# %%
a.remove('dog')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-5083c940c731> in <cell line: 0>()
# ----> 1 a.remove('dog')
#
# KeyError: 'dog'

# %%
# in 연산자
'bird' in a
# Out:
# False

# %%
'cat' in a
# Out:
# True
